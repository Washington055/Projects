# %% [markdown]
# <a href="https://colab.research.google.com/github/Washington055/Python-EDA/blob/main/Movie_Correlation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
df = files.upload()
# Out:
#      <input type="file" id="files-e5423e12-1ec0-4fd4-9a88-7ed91a2b7763" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e5423e12-1ec0-4fd4-9a88-7ed91a2b7763">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import matplotlib
from ast import increment_lineno
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
plt.style.use("ggplot")
from matplotlib.pyplot import figure
# %matplotlib inline 
matplotlib.rcParams['figure.figsize']=(20,10)

import seaborn as sns

# %%
df = pd.read_csv("movies.csv")

# %%
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
df.isnull().sum()
# Out:
# name           0
# rating        77
# genre          0
# year           0
# released       2
# score          3
# votes          3
# director       0
# writer         3
# star           1
# country        3
# budget      2171
# gross        189
# company       17
# runtime        4
# dtype: int64

# %%
for col in df.columns:
    pct_missing = round((np.mean(df[col].isnull())*100),2)
    print ('{} = {}%'.format(col,pct_missing ))
# Out:
# name = 0.0%
# rating = 1.0%
# genre = 0.0%
# year = 0.0%
# released = 0.03%
# score = 0.04%
# votes = 0.04%
# director = 0.0%
# writer = 0.04%
# star = 0.01%
# country = 0.04%
# budget = 28.31%
# gross = 2.46%
# company = 0.22%
# runtime = 0.05%

# %%
df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
df['released'].astype('str')
# Out:
# 0          June 13, 1980 (United States)
# 1           July 2, 1980 (United States)
# 2          June 20, 1980 (United States)
# 3           July 2, 1980 (United States)
# 4          July 25, 1980 (United States)
#                       ...
# 7663    October 23, 2020 (United States)
# 7664    February 7, 2020 (United States)
# 7665           April 27, 2020 (Cameroon)
# 7666     October 1, 2020 (United States)
# 7667     August 19, 2020 (United States)
# Name: released, Length: 7668, dtype: object

# %%
# create a year correct colum
df['yearcorrect'] = df['released'].str.split(' ',expand=True)[2]

# %%
df.head(10)
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
# 5                                 Friday the 13th      R     Horror  1980
# 6                              The Blues Brothers      R     Action  1980
# 7                                     Raging Bull      R  Biography  1980
# 8                                     Superman II     PG     Action  1980
# 9                                 The Long Riders      R  Biography  1980
#
#                             released  score      votes            director  \
# 0      June 13, 1980 (United States)    8.4   927000.0     Stanley Kubrick
# ...

# %%
df = df.sort_values(by=['budget'],inplace=False, ascending=False)

# %%
pd.set_option('display.max_rows', None)

# %%
# drop duplicates

df.drop_duplicates()
# Out:
#                                           name     rating   genre  year  \
# 7445                         Avengers: Endgame      PG-13  Action  2019
# 7244                    Avengers: Infinity War      PG-13  Action  2018
# 7075   Star Wars: Episode VIII - The Last Jedi      PG-13  Action  2017
# 7066                            Justice League      PG-13  Action  2017
# 5060  Pirates of the Caribbean: at World's End      PG-13  Action  2007
# ...                                        ...        ...     ...   ...
# 7657                                      Leap        NaN   Drama  2020
# 7659                                 I Am Fear  Not Rated  Horror  2020
# 7660                          Aloha Surf Hotel        NaN  Comedy  2020
# 7664                               Dream Round        NaN  Comedy  2020
# 7667                                 Tee em el        NaN  Horror  2020
#
#                                 released  score     votes            director  \
# ...

# %%
df1 = df.sort_values(by=['gross'],inplace = False,ascending=False)

# %%
df.columns
# Out:
# Index(['name', 'rating', 'genre', 'year', 'released', 'score', 'votes',
#        'director', 'writer', 'star', 'country', 'budget', 'gross', 'company',
#        'runtime', 'yearcorrect'],
#       dtype='object')

# %%
df.dtypes
# Out:
# name            object
# rating          object
# genre           object
# year             int64
# released        object
# score          float64
# votes          float64
# director        object
# writer          object
# star            object
# country         object
# budget         float64
# gross          float64
# company         object
# runtime        float64
# yearcorrect     object
# dtype: object

# %%
sns.countplot(x='genre', data=df)

# %%
sns.pairplot(data=df)

# %%
df_corr = df.corr(method="spearman")
df_corr
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.099045  0.469829  0.317336  0.293084  0.142977
# score    0.099045  1.000000  0.428138 -0.001403  0.126116  0.399857
# votes    0.469829  0.428138  1.000000  0.502466  0.742050  0.290159
# budget   0.317336 -0.001403  0.502466  1.000000  0.693670  0.336370
# gross    0.293084  0.126116  0.742050  0.693670  1.000000  0.246243
# runtime  0.142977  0.399857  0.290159  0.336370  0.246243  1.000000

# %%
sns.heatmap(df_corr,
            xticklabels=df_corr.columns,
            yticklabels=df_corr.columns,
            cmap="coolwarm", annot=True)

# %%
# budget and gross correlation

# %%
plt.scatter(x=df['votes'],y=df['gross'])
plt.xlabel('votes')
plt.ylabel('gross')
plt.title('Correlation') 
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
df.head(3)
# Out:
#                    name rating   genre  year  \
# 5445             Avatar  PG-13  Action  2009
# 7445  Avengers: Endgame  PG-13  Action  2019
# 3045            Titanic  PG-13   Drama  1997
#
#                                released  score      votes       director  \
# 5445  December 18, 2009 (United States)    7.8  1100000.0  James Cameron
# 7445     April 26, 2019 (United States)    8.4   903000.0  Anthony Russo
# 3045  December 19, 1997 (United States)    7.8  1100000.0  James Cameron
#
#                   writer               star        country       budget  \
# 5445       James Cameron    Sam Worthington  United States  237000000.0
# 7445  Christopher Markus  Robert Downey Jr.  United States  356000000.0
# 3045       James Cameron  Leonardo DiCaprio  United States  200000000.0
#
#              gross                company  runtime yearcorrect
# 5445  2.847246e+09  Twentieth Century Fox    162.0        2009
# 7445  2.797501e+09         Marvel Studios    181.0        2019
# ...

# %%
sns.regplot(x='votes', y='gross', data = df, scatter_kws={"color":"red"}, line_kws={"color":"blue"})

# %%
#pearson, spearman, kendall
corr_matriz = df.corr(method="pearson")
corr_matriz
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.097995  0.222945  0.329321  0.257486  0.120811
# score    0.097995  1.000000  0.409182  0.076254  0.186258  0.399451
# votes    0.222945  0.409182  1.000000  0.442429  0.630757  0.309212
# budget   0.329321  0.076254  0.442429  1.000000  0.740395  0.320447
# gross    0.257486  0.186258  0.630757  0.740395  1.000000  0.245216
# runtime  0.120811  0.399451  0.309212  0.320447  0.245216  1.000000

# %%
sns.heatmap(corr_matriz,
            xticklabels=corr_matriz.columns,
            yticklabels=corr_matriz.columns,
            annot=True)
plt.show()

# %%
df_num = df
for col_name in df_num.columns:
    if(df_num[col_name].dtype =="object"):
      df_num[col_name]=df_num[col_name].astype("category")
      df_num[col_name]=df_num[col_name].cat.codes
df_num.head(5)
# Out:
#       name  rating  genre  year  released  score      votes  director  writer  \
# 5445   533       5      0  2009       696    7.8  1100000.0      1155    1778
# 7445   535       5      0  2019       183    8.4   903000.0       162     743
# 3045  6896       5      6  1997       704    7.8  1100000.0      1155    1778
# 6663  5144       5      0  2015       698    7.8   876000.0      1125    2550
# 7244   536       5      0  2018       192    8.4   897000.0       162     743
#
#       star  country       budget         gross  company  runtime  yearcorrect
# 5445  2334       55  237000000.0  2.847246e+09     2253    162.0           31
# 7445  2241       55  356000000.0  2.797501e+09     1606    181.0           41
# 3045  1595       55  200000000.0  2.201647e+09     2253    194.0           19
# 6663   524       55  245000000.0  2.069522e+09     1540    138.0           37
# 7244  2241       55  321000000.0  2.048360e+09     1606    149.0           40

# %%
df1.head(5)
# Out:
#                                             name rating   genre  year  \
# 5445                                      Avatar  PG-13  Action  2009
# 7445                           Avengers: Endgame  PG-13  Action  2019
# 3045                                     Titanic  PG-13   Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13  Action  2015
# 7244                      Avengers: Infinity War  PG-13  Action  2018
#
#                                released  score      votes       director  \
# 5445  December 18, 2009 (United States)    7.8  1100000.0  James Cameron
# 7445     April 26, 2019 (United States)    8.4   903000.0  Anthony Russo
# 3045  December 19, 1997 (United States)    7.8  1100000.0  James Cameron
# 6663  December 18, 2015 (United States)    7.8   876000.0    J.J. Abrams
# 7244     April 27, 2018 (United States)    8.4   897000.0  Anthony Russo
#
#                   writer               star        country       budget  \
# ...

# %%
corr_matriz = df_num.corr(method="pearson")
corr_matriz 
sns.heatmap(corr_matriz,
            xticklabels=corr_matriz.columns,
            yticklabels=corr_matriz.columns,
            annot=True)
plt.show()

# %%
df_num.corr()
# Out:
#                  name    rating     genre      year  released     score  \
# name         1.000000 -0.008069  0.016355  0.011453 -0.011311  0.017097
# rating      -0.008069  1.000000  0.072423  0.008779  0.016613 -0.001314
# genre        0.016355  0.072423  1.000000 -0.081261  0.029822  0.027965
# year         0.011453  0.008779 -0.081261  1.000000 -0.000695  0.097995
# released    -0.011311  0.016613  0.029822 -0.000695  1.000000  0.042788
# score        0.017097 -0.001314  0.027965  0.097995  0.042788  1.000000
# votes        0.013088  0.033225 -0.145307  0.222945  0.016097  0.409182
# director     0.009079  0.019483 -0.015258 -0.020795 -0.001478  0.009559
# writer       0.009081 -0.005921  0.006567 -0.008656 -0.002404  0.019416
# star         0.006472  0.013405 -0.005477 -0.027242  0.015777 -0.001609
# country     -0.010737  0.081244 -0.037615 -0.070938 -0.020427 -0.133348
# budget       0.023970 -0.176002 -0.356564  0.329321  0.014683  0.076254
# ...

# %%
corr_mat = df_num.corr()
corr_pairs= corr_mat.unstack()
corr_pairs
# Out:
# name         name           1.000000
#              rating        -0.008069
#              genre          0.016355
#              year           0.011453
#              released      -0.011311
#                               ...
# yearcorrect  budget         0.321894
#              gross          0.250527
#              company       -0.011060
#              runtime        0.120976
#              yearcorrect    1.000000
# Length: 256, dtype: float64

# %%
sorted_pairs = corr_pairs.sort_values()
sorted_pairs
# Out:
# genre        budget        -0.356564
# budget       genre         -0.356564
# genre        gross         -0.235650
# gross        genre         -0.235650
# rating       budget        -0.176002
#                               ...
# year         year           1.000000
# genre        genre          1.000000
# rating       rating         1.000000
# runtime      runtime        1.000000
# yearcorrect  yearcorrect    1.000000
# Length: 256, dtype: float64

# %%
hight_corr = sorted_pairs[(sorted_pairs)>0.5] 
hight_corr
# Out:
# votes        gross          0.630757
# gross        votes          0.630757
#              budget         0.740395
# budget       gross          0.740395
# year         yearcorrect    0.990063
# yearcorrect  year           0.990063
# name         name           1.000000
# company      company        1.000000
# gross        gross          1.000000
# budget       budget         1.000000
# country      country        1.000000
# star         star           1.000000
# writer       writer         1.000000
# director     director       1.000000
# votes        votes          1.000000
# score        score          1.000000
# released     released       1.000000
# year         year           1.000000
# genre        genre          1.000000
# rating       rating         1.000000
# runtime      runtime        1.000000
# yearcorrect  yearcorrect    1.000000
# dtype: float64
