# %% [markdown]
# <a href="https://colab.research.google.com/github/Washington055/Python-EDA/blob/main/Reemplazar_valores.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Replacement values

# %%
from google.colab import files
datos= files.upload()
# Out:
#      <input type="file" id="files-387b2106-6fbd-446f-9fba-fb56c0160c82" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-387b2106-6fbd-446f-9fba-fb56c0160c82">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Niveles de contaminacion.csv to Niveles de contaminacion.csv

# %%
#import libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
niveles=pd.read_csv("Niveles de contaminacion.csv")

# %%
niveles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33 entries, 0 to 32
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Numero_de_empresas  33 non-null     int64
#  1   PM10                33 non-null     int64
#  2   PM2.5               29 non-null     float64
#  3   SO2                 32 non-null     float64
#  4   CO                  33 non-null     int64
#  5   NOX                 25 non-null     float64
#  6   COV                 33 non-null     int64
#  7   NH3                 33 non-null     int64
#  8   CN                  25 non-null     float64
# dtypes: float64(4), int64(5)
# memory usage: 2.4 KB

# %%
niveles.isnull().sum()
# Out:
# Numero_de_empresas    0
# PM10                  0
# PM2.5                 4
# SO2                   1
# CO                    0
# NOX                   8
# COV                   0
# NH3                   0
# CN                    8
# dtype: int64

# %%
niveles
# Out:
#     Numero_de_empresas   PM10    PM2.5       SO2      CO       NOX    COV  \
# 0                    0    945    629.0    1814.0     235     843.0   1836
# 1                  588   1978   1842.0    5588.0    6850       NaN  11692
# 2                   27   1028    752.0   22890.0     505       NaN    516
# 3                   39   4527   3847.0  574973.0    8698   34132.0   3465
# 4                  214   5063   3083.0   54592.0    2510    4845.0   3419
# 5                   34   3360      NaN   33287.0    9505   11015.0   4741
# 6                   42  19963  16177.0  190970.0   24171  158743.0   6202
# 7                  367   8207   4958.0  166476.0    1767   20578.0   1296
# 8                 1569   1381    826.0     699.0     766    2217.0  21967
# 9                   80   2971      NaN   27144.0    2930    6645.0   3156
# 10                 233   3810   2770.0   48462.0   74299    9249.0  10155
# 11                   8   8215   7725.0  104172.0    2327   11206.0    708
# ...

# %%
niveles1=niveles.fillna(0)
niveles1
# Out:
#     Numero_de_empresas   PM10    PM2.5       SO2      CO       NOX    COV  \
# 0                    0    945    629.0    1814.0     235     843.0   1836
# 1                  588   1978   1842.0    5588.0    6850       0.0  11692
# 2                   27   1028    752.0   22890.0     505       0.0    516
# 3                   39   4527   3847.0  574973.0    8698   34132.0   3465
# 4                  214   5063   3083.0   54592.0    2510    4845.0   3419
# 5                   34   3360      0.0   33287.0    9505   11015.0   4741
# 6                   42  19963  16177.0  190970.0   24171  158743.0   6202
# 7                  367   8207   4958.0  166476.0    1767   20578.0   1296
# 8                 1569   1381    826.0     699.0     766    2217.0  21967
# 9                   80   2971      0.0   27144.0    2930    6645.0   3156
# 10                 233   3810   2770.0   48462.0   74299    9249.0  10155
# 11                   8   8215   7725.0  104172.0    2327   11206.0    708
# ...

# %%
niveles2= niveles.apply(lambda x:x.fillna(x.mean()),axis=0)
niveles2
# Out:
#     Numero_de_empresas   PM10         PM2.5           SO2      CO        NOX  \
# 0                    0    945    629.000000    1814.00000     235     843.00
# 1                  588   1978   1842.000000    5588.00000    6850   18707.28
# 2                   27   1028    752.000000   22890.00000     505   18707.28
# 3                   39   4527   3847.000000  574973.00000    8698   34132.00
# 4                  214   5063   3083.000000   54592.00000    2510    4845.00
# 5                   34   3360   4909.482759   33287.00000    9505   11015.00
# 6                   42  19963  16177.000000  190970.00000   24171  158743.00
# 7                  367   8207   4958.000000  166476.00000    1767   20578.00
# 8                 1569   1381    826.000000     699.00000     766    2217.00
# 9                   80   2971   4909.482759   27144.00000    2930    6645.00
# 10                 233   3810   2770.000000   48462.00000   74299    9249.00
# ...

# %%
niveles3= niveles.apply(lambda x:x.fillna(x.median()),axis=0)
niveles3
# Out:
#     Numero_de_empresas   PM10    PM2.5       SO2      CO       NOX    COV  \
# 0                    0    945    629.0    1814.0     235     843.0   1836
# 1                  588   1978   1842.0    5588.0    6850   10184.0  11692
# 2                   27   1028    752.0   22890.0     505   10184.0    516
# 3                   39   4527   3847.0  574973.0    8698   34132.0   3465
# 4                  214   5063   3083.0   54592.0    2510    4845.0   3419
# 5                   34   3360   3460.0   33287.0    9505   11015.0   4741
# 6                   42  19963  16177.0  190970.0   24171  158743.0   6202
# 7                  367   8207   4958.0  166476.0    1767   20578.0   1296
# 8                 1569   1381    826.0     699.0     766    2217.0  21967
# 9                   80   2971   3460.0   27144.0    2930    6645.0   3156
# 10                 233   3810   2770.0   48462.0   74299    9249.0  10155
# 11                   8   8215   7725.0  104172.0    2327   11206.0    708
# ...

# %%
niveles.drop_duplicates()
# Out:
#     Numero_de_empresas   PM10    PM2.5       SO2      CO       NOX    COV  \
# 0                    0    945    629.0    1814.0     235     843.0   1836
# 1                  588   1978   1842.0    5588.0    6850       NaN  11692
# 2                   27   1028    752.0   22890.0     505       NaN    516
# 3                   39   4527   3847.0  574973.0    8698   34132.0   3465
# 4                  214   5063   3083.0   54592.0    2510    4845.0   3419
# 5                   34   3360      NaN   33287.0    9505   11015.0   4741
# 6                   42  19963  16177.0  190970.0   24171  158743.0   6202
# 7                  367   8207   4958.0  166476.0    1767   20578.0   1296
# 8                 1569   1381    826.0     699.0     766    2217.0  21967
# 9                   80   2971      NaN   27144.0    2930    6645.0   3156
# 10                 233   3810   2770.0   48462.0   74299    9249.0  10155
# 11                   8   8215   7725.0  104172.0    2327   11206.0    708
# ...

# %%
niveles.dropna(thresh=8)
# Out:
#     Numero_de_empresas   PM10    PM2.5       SO2      CO       NOX    COV  \
# 0                    0    945    629.0    1814.0     235     843.0   1836
# 2                   27   1028    752.0   22890.0     505       NaN    516
# 3                   39   4527   3847.0  574973.0    8698   34132.0   3465
# 4                  214   5063   3083.0   54592.0    2510    4845.0   3419
# 5                   34   3360      NaN   33287.0    9505   11015.0   4741
# 6                   42  19963  16177.0  190970.0   24171  158743.0   6202
# 7                  367   8207   4958.0  166476.0    1767   20578.0   1296
# 8                 1569   1381    826.0     699.0     766    2217.0  21967
# 9                   80   2971      NaN   27144.0    2930    6645.0   3156
# 10                 233   3810   2770.0   48462.0   74299    9249.0  10155
# 11                   8   8215   7725.0  104172.0    2327   11206.0    708
# 12                 129  12532   8977.0  216611.0  115085   31484.0   7567
# ...

# %%
niveles.std()
# Out:
# Numero_de_empresas       346.377356
# PM10                    7711.727059
# PM2.5                   5258.749638
# SO2                   110163.166286
# CO                     34131.505325
# NOX                    31415.400186
# COV                    10278.400976
# NH3                     1474.116431
# CN                      1081.491467
# dtype: float64

# %%
niveles.mean()
# Out:
# Numero_de_empresas      233.090909
# PM10                   6565.636364
# PM2.5                  4909.482759
# SO2                   69570.406250
# CO                    19161.121212
# NOX                   18707.280000
# COV                    8096.242424
# NH3                     896.424242
# CN                      597.720000
# dtype: float64
